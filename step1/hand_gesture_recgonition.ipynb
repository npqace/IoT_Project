# %%
# Tạo folder data để các bạn upload file 3 file data được tạo ra ở step 0 vào folder data
# Các bạn upload file hand_gesture.yaml ngoài folder data
# !mkdir data/

# %%
# Nếu đã chạy thành công step 0 thì các bạn không chạy cell này và chỉ upload 3 file data của các bạn vào thư mục data
# Và upload file hand_gesture.yaml bên ngoài thư mục data
# Nếu không chạy được ở step 0 thì các bạn run cell này để download data
# !gdown  1gzWOtABiVmJ38usCSDe5F9gR2tECt3zu -O data/
# !gdown  15lwipssmC_K82ukRfb0uVCiDH1TZ3QCf -O data/
# !gdown  1nIo1_wBmkovz-u_BCsV5c1Kbz6ZqoKwq -O data/
# Download file hand_gesture.yam
# !gdown  1ZteHYSgbuZu_GcUJHW8ZzoZv1DE8-oLw

# %%
# !pip install mediapipe==0.10.18
# Out:
# Collecting mediapipe==0.10.18
#   Downloading mediapipe-0.10.18-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.7 kB)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from mediapipe==0.10.18) (1.4.0)
# Requirement already satisfied: attrs>=19.1.0 in /usr/local/lib/python3.10/dist-packages (from mediapipe==0.10.18) (24.2.0)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.10/dist-packages (from mediapipe==0.10.18) (24.3.25)
# Requirement already satisfied: jax in /usr/local/lib/python3.10/dist-packages (from mediapipe==0.10.18) (0.4.33)
# Requirement already satisfied: jaxlib in /usr/local/lib/python3.10/dist-packages (from mediapipe==0.10.18) (0.4.33)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mediapipe==0.10.18) (3.8.0)
# Requirement already satisfied: numpy<2 in /usr/local/lib/python3.10/dist-packages (from mediapipe==0.10.18) (1.26.4)
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.10/dist-packages (from mediapipe==0.10.18) (4.10.0.84)
# Requirement already satisfied: protobuf<5,>=4.25.3 in /usr/local/lib/python3.10/dist-packages (from mediapipe==0.10.18) (4.25.5)
# Collecting sounddevice>=0.4.4 (from mediapipe==0.10.18)
#   Downloading sounddevice-0.5.1-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from mediapipe==0.10.18) (0.2.0)
# Requirement already satisfied: CFFI>=1.0 in /usr/local/lib/python3.10/dist-packages (from sounddevice>=0.4.4->mediapipe==0.10.18) (1.17.1)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from jax->mediapipe==0.10.18) (0.4.1)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.10/dist-packages (from jax->mediapipe==0.10.18) (3.4.0)
# Requirement already satisfied: scipy>=1.10 in /usr/local/lib/python3.10/dist-packages (from jax->mediapipe==0.10.18) (1.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe==0.10.18) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe==0.10.18) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe==0.10.18) (4.55.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe==0.10.18) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe==0.10.18) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe==0.10.18) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe==0.10.18) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe==0.10.18) (2.8.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe==0.10.18) (2.22)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mediapipe==0.10.18) (1.16.0)
# Downloading mediapipe-0.10.18-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (36.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.1/36.1 MB 54.8 MB/s eta 0:00:00
# Downloading sounddevice-0.5.1-py3-none-any.whl (32 kB)
# Installing collected packages: sounddevice, mediapipe
# Successfully installed mediapipe-0.10.18 sounddevice-0.5.1

# %%
# !pip install torchmetrics
# Out:
# Collecting torchmetrics
#   Downloading torchmetrics-1.6.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: numpy>1.20.0 in /usr/local/lib/python3.10/dist-packages (from torchmetrics) (1.26.4)
# Requirement already satisfied: packaging>17.1 in /usr/local/lib/python3.10/dist-packages (from torchmetrics) (24.2)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from torchmetrics) (2.5.1+cu121)
# Collecting lightning-utilities>=0.8.0 (from torchmetrics)
#   Downloading lightning_utilities-0.11.9-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from lightning-utilities>=0.8.0->torchmetrics) (75.1.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from lightning-utilities>=0.8.0->torchmetrics) (4.12.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->torchmetrics) (3.16.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->torchmetrics) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->torchmetrics) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->torchmetrics) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->torchmetrics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=2.0.0->torchmetrics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=2.0.0->torchmetrics) (3.0.2)
# Downloading torchmetrics-1.6.0-py3-none-any.whl (926 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 926.4/926.4 kB 15.0 MB/s eta 0:00:00
# Downloading lightning_utilities-0.11.9-py3-none-any.whl (28 kB)
# Installing collected packages: lightning-utilities, torchmetrics
# Successfully installed lightning-utilities-0.11.9 torchmetrics-1.6.0

# %%
import os
import cv2
import yaml
import torch
import numpy as np
import pandas as pd
from  torch import nn
import mediapipe as mp
from torch import optim
from datetime import datetime
from torchmetrics import Accuracy
from torch.utils.data import Dataset

# %%
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.flatten = nn.Flatten()
        list_label = label_dict_from_config_file("hand_gesture.yaml")

        self.linear_relu_stack = nn.Sequential(
            nn.Linear(63, 128),
            nn.ReLU(),
            nn.BatchNorm1d(128),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Dropout(p=0.4),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Dropout(p=0.4),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Dropout(p=0.6),
            nn.Linear(128, len(list_label))
        )
    def forward(self, x):
        x = self.flatten(x)
        x = self.linear_relu_stack(x)
        return x

    def predict(self,x,threshold=0.8):
        logits = self(x)
        softmax_prob = nn.Softmax(dim=1)(logits)
        chosen_ind = torch.argmax(softmax_prob,dim=1)
        return torch.where(softmax_prob[0,chosen_ind]>threshold,chosen_ind,-1)

    def predict_with_known_class(self,x):
        logits = self(x)
        softmax_prob = nn.Softmax(dim=1)(logits)
        return torch.argmax(softmax_prob,dim=1)

    def score(self,logits):
        return -torch.amax(logits,dim=1)

# %%
def label_dict_from_config_file(relative_path):
    with open(relative_path,"r") as f:
       label_tag = yaml.full_load(f)["gestures"]
    return label_tag

# %%
class HandLandmarksDetector():
    def __init__(self) -> None:
        self.mp_drawing = mp.solutions.drawing_utils
        self.mp_drawing_styles = mp.solutions.drawing_styles
        self.mp_hands = mp.solutions.hands
        self.detector = self.mp_hands.Hands(False,max_num_hands=1,min_detection_confidence=0.5)

    def detectHand(self,frame):
        hands = []
        frame = cv2.flip(frame, 1)
        annotated_image = frame.copy()
        results = self.detector.process(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
        if results.multi_hand_landmarks is not None:
            for hand_landmarks in results.multi_hand_landmarks:
                hand = []
                self.mp_drawing.draw_landmarks(
                    annotated_image,
                    hand_landmarks,
                    self.mp_hands.HAND_CONNECTIONS,
                    self.mp_drawing_styles.get_default_hand_landmarks_style(),
                    self.mp_drawing_styles.get_default_hand_connections_style())
                for landmark in hand_landmarks.landmark:
                    x,y,z = landmark.x,landmark.y,landmark.z
                    hand.extend([x,y,z])
            hands.append(hand)
        return hands,annotated_image

# %%
class CustomImageDataset(Dataset):
    def __init__(self, data_file):
        self.data = pd.read_csv(data_file)
        self.labels = torch.from_numpy(self.data.iloc[:,0].to_numpy())

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        one_hot_label = self.labels[idx]
        torch_data = torch.from_numpy(self.data.iloc[idx,1:].to_numpy(dtype=np.float32))
        return torch_data, one_hot_label

# %%
class EarlyStopper:
    def __init__(self, patience=1, min_delta=0):
        self.patience = patience
        self.min_delta = min_delta
        self.counter = 0
        self.watched_metrics = np.inf

    def early_stop(self, current_value):
        if current_value < self.watched_metrics:
            self.watched_metrics = current_value
            self.counter = 0
        elif current_value > (self.watched_metrics + self.min_delta):
            self.counter += 1
            if self.counter >= self.patience:
                return True
        return False

# %%
def train(trainloader, val_loader, model, loss_function, early_stopper, optimizer):
    # add auroc score
    best_vloss = 1_000_000
    timestamp = datetime.now().strftime('%d-%m %H:%M')
    for epoch in range(300):
        #training step
        model.train(True)
        running_loss = 0.0
        acc_train = Accuracy(num_classes=len(LIST_LABEL), task='MULTICLASS')
        for batch_number,data in enumerate(trainloader):
            inputs,labels = data
            optimizer.zero_grad()
            preds = model(inputs)
            loss = loss_function(preds, labels)
            loss.backward()
            optimizer.step()
            acc_train.update(model.predict_with_known_class(inputs), labels)
            running_loss += loss.item()
        avg_loss = running_loss / len(trainloader)
        # validating step
        model.train(False)
        running_vloss = 0.0
        acc_val = Accuracy(num_classes=len(LIST_LABEL), task='MULTICLASS')
        for i, vdata in enumerate(val_loader):
            vinputs, vlabels = vdata
            preds = model(vinputs)
            vloss = loss_function(preds, vlabels)
            running_vloss += vloss.item()
            acc_val.update(model.predict_with_known_class(vinputs), vlabels)

        # Log the running loss averaged per batch
        # for both training and validation
        print(f"Epoch {epoch}: ")
        print(f"Accuracy train:{acc_train.compute().item()}, val:{acc_val.compute().item()}")
        avg_vloss = running_vloss / len(val_loader)
        print('LOSS train {} valid {}'.format(avg_loss, avg_vloss))
        print('Training vs. Validation Loss',
                        { 'Training' : avg_loss, 'Validation' : avg_vloss },
                        epoch + 1)
        print('Training vs. Validation accuracy',
                        { 'Training' : acc_train.compute().item()
                        , 'Validation' : acc_val.compute().item() },
                        epoch + 1)

        # Track best performance, and save the model's state
        if avg_vloss < best_vloss:
            best_vloss = avg_vloss
            best_model_path = f'./{save_path}/model_{timestamp}_{model.__class__.__name__}_best'
            torch.save(model.state_dict(), best_model_path)

        if early_stopper.early_stop(avg_vloss):
            print(f"stopping at epoch {epoch}, minimum: {early_stopper.watched_metrics}")
            break

    model_path = f'./{save_path}/model_{timestamp}_{model.__class__.__name__}_last'
    torch.save(model.state_dict(), model_path)

    print(acc_val.compute())
    return model, best_model_path

# %%
DATA_FOLDER_PATH="./data/"
LIST_LABEL = label_dict_from_config_file("hand_gesture.yaml")
train_path = os.path.join(DATA_FOLDER_PATH,"landmark_train.csv")
val_path = os.path.join(DATA_FOLDER_PATH,"landmark_val.csv")
save_path = './models'
os.makedirs(save_path,exist_ok=True)

trainset = CustomImageDataset(train_path)
trainloader = torch.utils.data.DataLoader(trainset ,batch_size =40, shuffle=True)

valset = CustomImageDataset(os.path.join(val_path))
val_loader = torch.utils.data.DataLoader(valset,batch_size=50, shuffle=False)
model = NeuralNetwork()
loss_function = nn.CrossEntropyLoss()
early_stopper = EarlyStopper(patience=30, min_delta=0.01)
optimizer = optim.Adam(model.parameters(), lr=0.0001)

model, best_model_path = train(trainloader, val_loader, model, loss_function, early_stopper, optimizer)
# Out:
# Epoch 0:
# Accuracy train:0.2563706636428833, val:0.3267090618610382
# LOSS train 1.5968381599946455 valid 1.5882296928992639
# Training vs. Validation Loss {'Training': 1.5968381599946455, 'Validation': 1.5882296928992639} 1
# Training vs. Validation accuracy {'Training': 0.2563706636428833, 'Validation': 0.3267090618610382} 1
# Epoch 1:
# Accuracy train:0.3729729652404785, val:0.6565977931022644
# LOSS train 1.559113040114894 valid 1.533779854957874
# Training vs. Validation Loss {'Training': 1.559113040114894, 'Validation': 1.533779854957874} 2
# Training vs. Validation accuracy {'Training': 0.3729729652404785, 'Validation': 0.6565977931022644} 2
# Epoch 2:
# Accuracy train:0.5498069524765015, val:0.6955484747886658
# LOSS train 1.4882986003702336 valid 1.4453223874935737
# Training vs. Validation Loss {'Training': 1.4882986003702336, 'Validation': 1.4453223874935737} 3
# Training vs. Validation accuracy {'Training': 0.5498069524765015, 'Validation': 0.6955484747886658} 3
# Epoch 3:
# Accuracy train:0.6277992129325867, val:0.7201907634735107
# LOSS train 1.3646229541662969 valid 1.3007469612818499
# Training vs. Validation Loss {'Training': 1.3646229541662969, 'Validation': 1.3007469612818499} 4
# Training vs. Validation accuracy {'Training': 0.6277992129325867, 'Validation': 0.7201907634735107} 4
# Epoch 4:
# Accuracy train:0.7050192952156067, val:0.7535771131515503
# LOSS train 1.19990002747738 valid 1.1336763627254045
# Training vs. Validation Loss {'Training': 1.19990002747738, 'Validation': 1.1336763627254045} 5
# Training vs. Validation accuracy {'Training': 0.7050192952156067, 'Validation': 0.7535771131515503} 5
# Epoch 5:
# Accuracy train:0.7822393774986267, val:0.8187599182128906
# LOSS train 1.0099524097009138 valid 0.9819626060242836
# Training vs. Validation Loss {'Training': 1.0099524097009138, 'Validation': 0.9819626060242836} 6
# Training vs. Validation accuracy {'Training': 0.7822393774986267, 'Validation': 0.8187599182128906} 6
# Epoch 6:
# Accuracy train:0.8532818555831909, val:0.8044515252113342
# LOSS train 0.8013091773697825 valid 0.8129559215158224
# Training vs. Validation Loss {'Training': 0.8013091773697825, 'Validation': 0.8129559215158224} 7
# Training vs. Validation accuracy {'Training': 0.8532818555831909, 'Validation': 0.8044515252113342} 7
# Epoch 7:
# Accuracy train:0.9050192832946777, val:0.8728139996528625
# LOSS train 0.584688250765656 valid 0.6120591918722942
# Training vs. Validation Loss {'Training': 0.584688250765656, 'Validation': 0.6120591918722942} 8
# Training vs. Validation accuracy {'Training': 0.9050192832946777, 'Validation': 0.8728139996528625} 8
# Epoch 8:
# Accuracy train:0.9258687496185303, val:0.9117646813392639
# LOSS train 0.4056892458236579 valid 0.4579097296541127
# Training vs. Validation Loss {'Training': 0.4056892458236579, 'Validation': 0.4579097296541127} 9
# Training vs. Validation accuracy {'Training': 0.9258687496185303, 'Validation': 0.9117646813392639} 9
# Epoch 9:
# Accuracy train:0.96138995885849, val:0.9531001448631287
# LOSS train 0.2802506843299577 valid 0.32221418101555455
# Training vs. Validation Loss {'Training': 0.2802506843299577, 'Validation': 0.32221418101555455} 10
# Training vs. Validation accuracy {'Training': 0.96138995885849, 'Validation': 0.9531001448631287} 10
# Epoch 10:
# Accuracy train:0.9791505932807922, val:0.9554848670959473
# LOSS train 0.19036778830217593 valid 0.24051732732018885
# Training vs. Validation Loss {'Training': 0.19036778830217593, 'Validation': 0.24051732732018885} 11
# Training vs. Validation accuracy {'Training': 0.9791505932807922, 'Validation': 0.9554848670959473} 11
# Epoch 11:
# Accuracy train:0.9907335638999939, val:0.9610492587089539
# LOSS train 0.11753497306596149 valid 0.1942061934924613
# Training vs. Validation Loss {'Training': 0.11753497306596149, 'Validation': 0.1942061934924613} 12
# Training vs. Validation accuracy {'Training': 0.9907335638999939, 'Validation': 0.9610492587089539} 12
# Epoch 12:
# Accuracy train:0.9899613857269287, val:0.9809221029281616
# LOSS train 0.09146749171795267 valid 0.13082623687716058
# Training vs. Validation Loss {'Training': 0.09146749171795267, 'Validation': 0.13082623687716058} 13
# Training vs. Validation accuracy {'Training': 0.9899613857269287, 'Validation': 0.9809221029281616} 13
# Epoch 13:
# Accuracy train:0.9915058016777039, val:0.9745628237724304
# LOSS train 0.07151286134665663 valid 0.1196494472768301
# Training vs. Validation Loss {'Training': 0.07151286134665663, 'Validation': 0.1196494472768301} 14
# Training vs. Validation accuracy {'Training': 0.9915058016777039, 'Validation': 0.9745628237724304} 14
# Epoch 14:
# Accuracy train:0.9938223958015442, val:0.9896661639213562
# LOSS train 0.06707205267792399 valid 0.10032673580392909
# Training vs. Validation Loss {'Training': 0.06707205267792399, 'Validation': 0.10032673580392909} 15
# Training vs. Validation accuracy {'Training': 0.9938223958015442, 'Validation': 0.9896661639213562} 15
# Epoch 15:
# Accuracy train:0.9969111680984497, val:0.9713831543922424
# LOSS train 0.0469567466414336 valid 0.09405728213963672
# Training vs. Validation Loss {'Training': 0.0469567466414336, 'Validation': 0.09405728213963672} 16
# Training vs. Validation accuracy {'Training': 0.9969111680984497, 'Validation': 0.9713831543922424} 16
# Epoch 16:
# Accuracy train:0.992277979850769, val:0.9848966598510742
# LOSS train 0.04084113999411012 valid 0.07262023468501866
# Training vs. Validation Loss {'Training': 0.04084113999411012, 'Validation': 0.07262023468501866} 17
# Training vs. Validation accuracy {'Training': 0.992277979850769, 'Validation': 0.9848966598510742} 17
# Epoch 17:
# Accuracy train:0.9953668117523193, val:0.975357711315155
# LOSS train 0.03974997314314047 valid 0.08160109872607371
# Training vs. Validation Loss {'Training': 0.03974997314314047, 'Validation': 0.08160109872607371} 18
# Training vs. Validation accuracy {'Training': 0.9953668117523193, 'Validation': 0.975357711315155} 18
# Epoch 18:
# Accuracy train:0.9953668117523193, val:0.9880763292312622
# LOSS train 0.030777407640760594 valid 0.057445066756022595
# Training vs. Validation Loss {'Training': 0.030777407640760594, 'Validation': 0.057445066756022595} 19
# Training vs. Validation accuracy {'Training': 0.9953668117523193, 'Validation': 0.9880763292312622} 19
# Epoch 19:
# Accuracy train:0.9938223958015442, val:0.9761525988578796
# LOSS train 0.029304954082225308 valid 0.062588245410902
# Training vs. Validation Loss {'Training': 0.029304954082225308, 'Validation': 0.062588245410902} 20
# Training vs. Validation accuracy {'Training': 0.9938223958015442, 'Validation': 0.9761525988578796} 20
# Epoch 20:
# Accuracy train:0.9953668117523193, val:0.9848966598510742
# LOSS train 0.030229286445925634 valid 0.06520876111384356
# Training vs. Validation Loss {'Training': 0.030229286445925634, 'Validation': 0.06520876111384356} 21
# Training vs. Validation accuracy {'Training': 0.9953668117523193, 'Validation': 0.9848966598510742} 21
# Epoch 21:
# Accuracy train:0.9976834058761597, val:0.9777424335479736
# LOSS train 0.023271903056990017 valid 0.06699671033913127
# Training vs. Validation Loss {'Training': 0.023271903056990017, 'Validation': 0.06699671033913127} 22
# Training vs. Validation accuracy {'Training': 0.9976834058761597, 'Validation': 0.9777424335479736} 22
# Epoch 22:
# Accuracy train:0.9961389899253845, val:0.9888712167739868
# LOSS train 0.023109038995409555 valid 0.04932352682674089
# Training vs. Validation Loss {'Training': 0.023109038995409555, 'Validation': 0.04932352682674089} 23
# Training vs. Validation accuracy {'Training': 0.9961389899253845, 'Validation': 0.9888712167739868} 23
# Epoch 23:
# Accuracy train:0.9984555840492249, val:0.9777424335479736
# LOSS train 0.017696812184471073 valid 0.05948783614775703
# Training vs. Validation Loss {'Training': 0.017696812184471073, 'Validation': 0.05948783614775703} 24
# Training vs. Validation accuracy {'Training': 0.9984555840492249, 'Validation': 0.9777424335479736} 24
# Epoch 24:
# Accuracy train:0.9953668117523193, val:0.9729729890823364
# LOSS train 0.018396185541694813 valid 0.07012684428935664
# Training vs. Validation Loss {'Training': 0.018396185541694813, 'Validation': 0.07012684428935664} 25
# Training vs. Validation accuracy {'Training': 0.9953668117523193, 'Validation': 0.9729729890823364} 25
# Epoch 25:
# Accuracy train:0.9976834058761597, val:0.9880763292312622
# LOSS train 0.019639757528872877 valid 0.043946544491168776
# Training vs. Validation Loss {'Training': 0.019639757528872877, 'Validation': 0.043946544491168776} 26
# Training vs. Validation accuracy {'Training': 0.9976834058761597, 'Validation': 0.9880763292312622} 26
# Epoch 26:
# Accuracy train:0.9984555840492249, val:0.9888712167739868
# LOSS train 0.017133368172146606 valid 0.0388401182920531
# Training vs. Validation Loss {'Training': 0.017133368172146606, 'Validation': 0.0388401182920531} 27
# Training vs. Validation accuracy {'Training': 0.9984555840492249, 'Validation': 0.9888712167739868} 27
# Epoch 27:
# Accuracy train:0.9976834058761597, val:0.9864864945411682
# LOSS train 0.013059523005998044 valid 0.0415833820678437
# Training vs. Validation Loss {'Training': 0.013059523005998044, 'Validation': 0.0415833820678437} 28
# Training vs. Validation accuracy {'Training': 0.9976834058761597, 'Validation': 0.9864864945411682} 28
# Epoch 28:
# Accuracy train:0.9976834058761597, val:0.9833068251609802
# LOSS train 0.012417734346606514 valid 0.0543423645265368
# Training vs. Validation Loss {'Training': 0.012417734346606514, 'Validation': 0.0543423645265368} 29
# Training vs. Validation accuracy {'Training': 0.9976834058761597, 'Validation': 0.9833068251609802} 29
# Epoch 29:
# Accuracy train:0.9984555840492249, val:0.9713831543922424
# LOSS train 0.013780295834735487 valid 0.0652185746050516
# Training vs. Validation Loss {'Training': 0.013780295834735487, 'Validation': 0.0652185746050516} 30
# Training vs. Validation accuracy {'Training': 0.9984555840492249, 'Validation': 0.9713831543922424} 30
# Epoch 30:
# Accuracy train:0.9969111680984497, val:0.9833068251609802
# LOSS train 0.012890722182805113 valid 0.04843999686230605
# Training vs. Validation Loss {'Training': 0.012890722182805113, 'Validation': 0.04843999686230605} 31
# Training vs. Validation accuracy {'Training': 0.9969111680984497, 'Validation': 0.9833068251609802} 31
# Epoch 31:
# Accuracy train:0.9969111680984497, val:0.9809221029281616
# LOSS train 0.009978387529510215 valid 0.048139295892164785
# Training vs. Validation Loss {'Training': 0.009978387529510215, 'Validation': 0.048139295892164785} 32
# Training vs. Validation accuracy {'Training': 0.9969111680984497, 'Validation': 0.9809221029281616} 32
# Epoch 32:
# Accuracy train:0.9984555840492249, val:0.9689984321594238
# LOSS train 0.009038577209029234 valid 0.06517716952280003
# Training vs. Validation Loss {'Training': 0.009038577209029234, 'Validation': 0.06517716952280003} 33
# Training vs. Validation accuracy {'Training': 0.9984555840492249, 'Validation': 0.9689984321594238} 33
# Epoch 33:
# Accuracy train:0.9984555840492249, val:0.9848966598510742
# LOSS train 0.015358240922179186 valid 0.04580329258554299
# Training vs. Validation Loss {'Training': 0.015358240922179186, 'Validation': 0.04580329258554299} 34
# Training vs. Validation accuracy {'Training': 0.9984555840492249, 'Validation': 0.9848966598510742} 34
# Epoch 34:
# Accuracy train:0.9984555840492249, val:0.9880763292312622
# LOSS train 0.011868987793356857 valid 0.04045431448828542
# Training vs. Validation Loss {'Training': 0.011868987793356857, 'Validation': 0.04045431448828542} 35
# Training vs. Validation accuracy {'Training': 0.9984555840492249, 'Validation': 0.9880763292312622} 35
# Epoch 35:
# Accuracy train:0.9984555840492249, val:0.9642289280891418
# LOSS train 0.014859994559435907 valid 0.08369885746794982
# Training vs. Validation Loss {'Training': 0.014859994559435907, 'Validation': 0.08369885746794982} 36
# Training vs. Validation accuracy {'Training': 0.9984555840492249, 'Validation': 0.9642289280891418} 36
# Epoch 36:
# Accuracy train:0.9984555840492249, val:0.9395866394042969
# LOSS train 0.016144740091862553 valid 0.1412952361594692
# Training vs. Validation Loss {'Training': 0.016144740091862553, 'Validation': 0.1412952361594692} 37
# Training vs. Validation accuracy {'Training': 0.9984555840492249, 'Validation': 0.9395866394042969} 37
# Epoch 37:
# Accuracy train:0.9984555840492249, val:0.9602543711662292
# LOSS train 0.01308339369257517 valid 0.09582934116308305
# Training vs. Validation Loss {'Training': 0.01308339369257517, 'Validation': 0.09582934116308305} 38
# Training vs. Validation accuracy {'Training': 0.9984555840492249, 'Validation': 0.9602543711662292} 38
# Epoch 38:
# Accuracy train:1.0, val:0.9745628237724304
# LOSS train 0.006403632105723249 valid 0.05459884320288648
# Training vs. Validation Loss {'Training': 0.006403632105723249, 'Validation': 0.05459884320288648} 39
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9745628237724304} 39
# Epoch 39:
# Accuracy train:0.9992278218269348, val:0.9546899795532227
# LOSS train 0.008504747906100061 valid 0.13990600972727826
# Training vs. Validation Loss {'Training': 0.008504747906100061, 'Validation': 0.13990600972727826} 40
# Training vs. Validation accuracy {'Training': 0.9992278218269348, 'Validation': 0.9546899795532227} 40
# Epoch 40:
# Accuracy train:1.0, val:0.973767876625061
# LOSS train 0.007088897352911194 valid 0.05870082477304095
# Training vs. Validation Loss {'Training': 0.007088897352911194, 'Validation': 0.05870082477304095} 41
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.973767876625061} 41
# Epoch 41:
# Accuracy train:0.9984555840492249, val:0.9658187627792358
# LOSS train 0.010889628120683923 valid 0.09236387257225523
# Training vs. Validation Loss {'Training': 0.010889628120683923, 'Validation': 0.09236387257225523} 42
# Training vs. Validation accuracy {'Training': 0.9984555840492249, 'Validation': 0.9658187627792358} 42
# Epoch 42:
# Accuracy train:1.0, val:0.975357711315155
# LOSS train 0.007301926154248191 valid 0.05413692503886453
# Training vs. Validation Loss {'Training': 0.007301926154248191, 'Validation': 0.05413692503886453} 43
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.975357711315155} 43
# Epoch 43:
# Accuracy train:0.9976834058761597, val:0.9817169904708862
# LOSS train 0.007161508808194688 valid 0.05421864256013228
# Training vs. Validation Loss {'Training': 0.007161508808194688, 'Validation': 0.05421864256013228} 44
# Training vs. Validation accuracy {'Training': 0.9976834058761597, 'Validation': 0.9817169904708862} 44
# Epoch 44:
# Accuracy train:0.9984555840492249, val:0.9825119376182556
# LOSS train 0.005193613875290435 valid 0.03681543184572652
# Training vs. Validation Loss {'Training': 0.005193613875290435, 'Validation': 0.03681543184572652} 45
# Training vs. Validation accuracy {'Training': 0.9984555840492249, 'Validation': 0.9825119376182556} 45
# Epoch 45:
# Accuracy train:0.9992278218269348, val:0.9825119376182556
# LOSS train 0.005785138325088404 valid 0.04481493509590214
# Training vs. Validation Loss {'Training': 0.005785138325088404, 'Validation': 0.04481493509590214} 46
# Training vs. Validation accuracy {'Training': 0.9992278218269348, 'Validation': 0.9825119376182556} 46
# Epoch 46:
# Accuracy train:1.0, val:0.9793322682380676
# LOSS train 0.00448167590939468 valid 0.04122373603113024
# Training vs. Validation Loss {'Training': 0.00448167590939468, 'Validation': 0.04122373603113024} 47
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9793322682380676} 47
# Epoch 47:
# Accuracy train:0.9969111680984497, val:0.973767876625061
# LOSS train 0.004759958138244904 valid 0.05580600068621887
# Training vs. Validation Loss {'Training': 0.004759958138244904, 'Validation': 0.05580600068621887} 48
# Training vs. Validation accuracy {'Training': 0.9969111680984497, 'Validation': 0.973767876625061} 48
# Epoch 48:
# Accuracy train:0.9984555840492249, val:0.972178041934967
# LOSS train 0.0026305614720155118 valid 0.053696273319570324
# Training vs. Validation Loss {'Training': 0.0026305614720155118, 'Validation': 0.053696273319570324} 49
# Training vs. Validation accuracy {'Training': 0.9984555840492249, 'Validation': 0.972178041934967} 49
# Epoch 49:
# Accuracy train:0.9992278218269348, val:0.9729729890823364
# LOSS train 0.003403726066497973 valid 0.05394236923627187
# Training vs. Validation Loss {'Training': 0.003403726066497973, 'Validation': 0.05394236923627187} 50
# Training vs. Validation accuracy {'Training': 0.9992278218269348, 'Validation': 0.9729729890823364} 50
# Epoch 50:
# Accuracy train:0.9992278218269348, val:0.9817169904708862
# LOSS train 0.006957504680471946 valid 0.04585588117284855
# Training vs. Validation Loss {'Training': 0.006957504680471946, 'Validation': 0.04585588117284855} 51
# Training vs. Validation accuracy {'Training': 0.9992278218269348, 'Validation': 0.9817169904708862} 51
# Epoch 51:
# Accuracy train:0.9984555840492249, val:0.9841017723083496
# LOSS train 0.008881854011137462 valid 0.04167498270262863
# Training vs. Validation Loss {'Training': 0.008881854011137462, 'Validation': 0.04167498270262863} 52
# Training vs. Validation accuracy {'Training': 0.9984555840492249, 'Validation': 0.9841017723083496} 52
# Epoch 52:
# Accuracy train:0.9961389899253845, val:0.980127215385437
# LOSS train 0.0083870313467218 valid 0.04783919107279207
# Training vs. Validation Loss {'Training': 0.0083870313467218, 'Validation': 0.04783919107279207} 53
# Training vs. Validation accuracy {'Training': 0.9961389899253845, 'Validation': 0.980127215385437} 53
# Epoch 53:
# Accuracy train:0.9992278218269348, val:0.9666136503219604
# LOSS train 0.007833690502483285 valid 0.06882193785636795
# Training vs. Validation Loss {'Training': 0.007833690502483285, 'Validation': 0.06882193785636795} 54
# Training vs. Validation accuracy {'Training': 0.9992278218269348, 'Validation': 0.9666136503219604} 54
# Epoch 54:
# Accuracy train:0.9992278218269348, val:0.9689984321594238
# LOSS train 0.008526165705089543 valid 0.07264451724433212
# Training vs. Validation Loss {'Training': 0.008526165705089543, 'Validation': 0.07264451724433212} 55
# Training vs. Validation accuracy {'Training': 0.9992278218269348, 'Validation': 0.9689984321594238} 55
# Epoch 55:
# Accuracy train:0.9992278218269348, val:0.9777424335479736
# LOSS train 0.0034577713835681084 valid 0.04345680105328798
# Training vs. Validation Loss {'Training': 0.0034577713835681084, 'Validation': 0.04345680105328798} 56
# Training vs. Validation accuracy {'Training': 0.9992278218269348, 'Validation': 0.9777424335479736} 56
# Epoch 56:
# Accuracy train:0.9992278218269348, val:0.9809221029281616
# LOSS train 0.0065640615145887505 valid 0.045705388782898544
# Training vs. Validation Loss {'Training': 0.0065640615145887505, 'Validation': 0.045705388782898544} 57
# Training vs. Validation accuracy {'Training': 0.9992278218269348, 'Validation': 0.9809221029281616} 57
# Epoch 57:
# Accuracy train:0.9992278218269348, val:0.9697933197021484
# LOSS train 0.0029433763543651862 valid 0.071690506380215
# Training vs. Validation Loss {'Training': 0.0029433763543651862, 'Validation': 0.071690506380215} 58
# Training vs. Validation accuracy {'Training': 0.9992278218269348, 'Validation': 0.9697933197021484} 58
# Epoch 58:
# Accuracy train:1.0, val:0.9833068251609802
# LOSS train 0.003447579329297172 valid 0.03941041715279644
# Training vs. Validation Loss {'Training': 0.003447579329297172, 'Validation': 0.03941041715279644} 59
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9833068251609802} 59
# Epoch 59:
# Accuracy train:1.0, val:0.9674085974693298
# LOSS train 0.0034474905052885524 valid 0.0728181975346073
# Training vs. Validation Loss {'Training': 0.0034474905052885524, 'Validation': 0.0728181975346073} 60
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9674085974693298} 60
# Epoch 60:
# Accuracy train:0.9984555840492249, val:0.980127215385437
# LOSS train 0.0025320944511225785 valid 0.04149312816743462
# Training vs. Validation Loss {'Training': 0.0025320944511225785, 'Validation': 0.04149312816743462} 61
# Training vs. Validation accuracy {'Training': 0.9984555840492249, 'Validation': 0.980127215385437} 61
# Epoch 61:
# Accuracy train:1.0, val:0.9697933197021484
# LOSS train 0.007026482332025118 valid 0.06137195392127436
# Training vs. Validation Loss {'Training': 0.007026482332025118, 'Validation': 0.06137195392127436} 62
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9697933197021484} 62
# Epoch 62:
# Accuracy train:0.9992278218269348, val:0.9586645364761353
# LOSS train 0.0059380141209465255 valid 0.07891548634034525
# Training vs. Validation Loss {'Training': 0.0059380141209465255, 'Validation': 0.07891548634034525} 63
# Training vs. Validation accuracy {'Training': 0.9992278218269348, 'Validation': 0.9586645364761353} 63
# Epoch 63:
# Accuracy train:1.0, val:0.9626390933990479
# LOSS train 0.0021373733783768716 valid 0.08818369443305475
# Training vs. Validation Loss {'Training': 0.0021373733783768716, 'Validation': 0.08818369443305475} 64
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9626390933990479} 64
# Epoch 64:
# Accuracy train:0.9984555840492249, val:0.9682034850120544
# LOSS train 0.0023042361728695332 valid 0.06395968716422938
# Training vs. Validation Loss {'Training': 0.0023042361728695332, 'Validation': 0.06395968716422938} 65
# Training vs. Validation accuracy {'Training': 0.9984555840492249, 'Validation': 0.9682034850120544} 65
# Epoch 65:
# Accuracy train:0.9992278218269348, val:0.970588207244873
# LOSS train 0.004795240513031427 valid 0.08023365161969966
# Training vs. Validation Loss {'Training': 0.004795240513031427, 'Validation': 0.08023365161969966} 66
# Training vs. Validation accuracy {'Training': 0.9992278218269348, 'Validation': 0.970588207244873} 66
# Epoch 66:
# Accuracy train:1.0, val:0.9904610514640808
# LOSS train 0.006003449357883779 valid 0.03321547024961328
# Training vs. Validation Loss {'Training': 0.006003449357883779, 'Validation': 0.03321547024961328} 67
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9904610514640808} 67
# Epoch 67:
# Accuracy train:1.0, val:0.9745628237724304
# LOSS train 0.003786480965738354 valid 0.07216781536417417
# Training vs. Validation Loss {'Training': 0.003786480965738354, 'Validation': 0.07216781536417417} 68
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9745628237724304} 68
# Epoch 68:
# Accuracy train:0.9992278218269348, val:0.9793322682380676
# LOSS train 0.002775774320815055 valid 0.057810730417665684
# Training vs. Validation Loss {'Training': 0.002775774320815055, 'Validation': 0.057810730417665684} 69
# Training vs. Validation accuracy {'Training': 0.9992278218269348, 'Validation': 0.9793322682380676} 69
# Epoch 69:
# Accuracy train:0.9992278218269348, val:0.9594594836235046
# LOSS train 0.002381845716930305 valid 0.09618227403988026
# Training vs. Validation Loss {'Training': 0.002381845716930305, 'Validation': 0.09618227403988026} 70
# Training vs. Validation accuracy {'Training': 0.9992278218269348, 'Validation': 0.9594594836235046} 70
# Epoch 70:
# Accuracy train:1.0, val:0.9602543711662292
# LOSS train 0.003632467252662702 valid 0.1120460200556158
# Training vs. Validation Loss {'Training': 0.003632467252662702, 'Validation': 0.1120460200556158} 71
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9602543711662292} 71
# Epoch 71:
# Accuracy train:1.0, val:0.9825119376182556
# LOSS train 0.00149410586395375 valid 0.058106168563277
# Training vs. Validation Loss {'Training': 0.00149410586395375, 'Validation': 0.058106168563277} 72
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9825119376182556} 72
# Epoch 72:
# Accuracy train:0.9984555840492249, val:0.980127215385437
# LOSS train 0.0019241090441496592 valid 0.04647183927946449
# Training vs. Validation Loss {'Training': 0.0019241090441496592, 'Validation': 0.04647183927946449} 73
# Training vs. Validation accuracy {'Training': 0.9984555840492249, 'Validation': 0.980127215385437} 73
# Epoch 73:
# Accuracy train:1.0, val:0.9634340405464172
# LOSS train 0.003924331003376706 valid 0.0842586006555647
# Training vs. Validation Loss {'Training': 0.003924331003376706, 'Validation': 0.0842586006555647} 74
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9634340405464172} 74
# Epoch 74:
# Accuracy train:0.9984555840492249, val:0.953895092010498
# LOSS train 0.002886480381262531 valid 0.11952644089925221
# Training vs. Validation Loss {'Training': 0.002886480381262531, 'Validation': 0.11952644089925221} 75
# Training vs. Validation accuracy {'Training': 0.9984555840492249, 'Validation': 0.953895092010498} 75
# Epoch 75:
# Accuracy train:0.9984555840492249, val:0.9602543711662292
# LOSS train 0.007865937327248199 valid 0.0972173504346144
# Training vs. Validation Loss {'Training': 0.007865937327248199, 'Validation': 0.0972173504346144} 76
# Training vs. Validation accuracy {'Training': 0.9984555840492249, 'Validation': 0.9602543711662292} 76
# Epoch 76:
# Accuracy train:1.0, val:0.9578696489334106
# LOSS train 0.0035505292983020117 valid 0.08561533549381185
# Training vs. Validation Loss {'Training': 0.0035505292983020117, 'Validation': 0.08561533549381185} 77
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9578696489334106} 77
# Epoch 77:
# Accuracy train:1.0, val:0.978537380695343
# LOSS train 0.0032464378314078645 valid 0.050202828765461706
# Training vs. Validation Loss {'Training': 0.0032464378314078645, 'Validation': 0.050202828765461706} 78
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.978537380695343} 78
# Epoch 78:
# Accuracy train:1.0, val:0.9745628237724304
# LOSS train 0.0021434214583926155 valid 0.055860137414747706
# Training vs. Validation Loss {'Training': 0.0021434214583926155, 'Validation': 0.055860137414747706} 79
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9745628237724304} 79
# Epoch 79:
# Accuracy train:0.9992278218269348, val:0.9809221029281616
# LOSS train 0.003144563675353614 valid 0.03620041087420899
# Training vs. Validation Loss {'Training': 0.003144563675353614, 'Validation': 0.03620041087420899} 80
# Training vs. Validation accuracy {'Training': 0.9992278218269348, 'Validation': 0.9809221029281616} 80
# Epoch 80:
# Accuracy train:1.0, val:0.9403815865516663
# LOSS train 0.004646160015413029 valid 0.22879282754616087
# Training vs. Validation Loss {'Training': 0.004646160015413029, 'Validation': 0.22879282754616087} 81
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9403815865516663} 81
# Epoch 81:
# Accuracy train:1.0, val:0.9507154226303101
# LOSS train 0.001993769657212507 valid 0.18394159086101397
# Training vs. Validation Loss {'Training': 0.001993769657212507, 'Validation': 0.18394159086101397} 82
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9507154226303101} 82
# Epoch 82:
# Accuracy train:0.9992278218269348, val:0.9443561434745789
# LOSS train 0.0012199340666429084 valid 0.19420148165589415
# Training vs. Validation Loss {'Training': 0.0012199340666429084, 'Validation': 0.19420148165589415} 83
# Training vs. Validation accuracy {'Training': 0.9992278218269348, 'Validation': 0.9443561434745789} 83
# Epoch 83:
# Accuracy train:0.9992278218269348, val:0.953895092010498
# LOSS train 0.0015174312464461598 valid 0.10521857465323155
# Training vs. Validation Loss {'Training': 0.0015174312464461598, 'Validation': 0.10521857465323155} 84
# Training vs. Validation accuracy {'Training': 0.9992278218269348, 'Validation': 0.953895092010498} 84
# Epoch 84:
# Accuracy train:0.9945945739746094, val:0.9546899795532227
# LOSS train 0.005516588037029247 valid 0.1451368409770551
# Training vs. Validation Loss {'Training': 0.005516588037029247, 'Validation': 0.1451368409770551} 85
# Training vs. Validation accuracy {'Training': 0.9945945739746094, 'Validation': 0.9546899795532227} 85
# Epoch 85:
# Accuracy train:1.0, val:0.9682034850120544
# LOSS train 0.002987974613929647 valid 0.09006648397206946
# Training vs. Validation Loss {'Training': 0.002987974613929647, 'Validation': 0.09006648397206946} 86
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9682034850120544} 86
# Epoch 86:
# Accuracy train:1.0, val:0.972178041934967
# LOSS train 0.0017272956979330488 valid 0.07489939199634649
# Training vs. Validation Loss {'Training': 0.0017272956979330488, 'Validation': 0.07489939199634649} 87
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.972178041934967} 87
# Epoch 87:
# Accuracy train:0.9992278218269348, val:0.9642289280891418
# LOSS train 0.0014009694052881307 valid 0.10684518795539497
# Training vs. Validation Loss {'Training': 0.0014009694052881307, 'Validation': 0.10684518795539497} 88
# Training vs. Validation accuracy {'Training': 0.9992278218269348, 'Validation': 0.9642289280891418} 88
# Epoch 88:
# Accuracy train:1.0, val:0.9777424335479736
# LOSS train 0.0017200815446730385 valid 0.04301219481999123
# Training vs. Validation Loss {'Training': 0.0017200815446730385, 'Validation': 0.04301219481999123} 89
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9777424335479736} 89
# Epoch 89:
# Accuracy train:1.0, val:0.9872813820838928
# LOSS train 0.0063239029628730905 valid 0.03814319946885492
# Training vs. Validation Loss {'Training': 0.0063239029628730905, 'Validation': 0.03814319946885492} 90
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9872813820838928} 90
# Epoch 90:
# Accuracy train:1.0, val:0.9650238752365112
# LOSS train 0.003864872829581145 valid 0.08039356773047555
# Training vs. Validation Loss {'Training': 0.003864872829581145, 'Validation': 0.08039356773047555} 91
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9650238752365112} 91
# Epoch 91:
# Accuracy train:1.0, val:0.9793322682380676
# LOSS train 0.0028742471340868206 valid 0.05032748139568956
# Training vs. Validation Loss {'Training': 0.0028742471340868206, 'Validation': 0.05032748139568956} 92
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9793322682380676} 92
# Epoch 92:
# Accuracy train:1.0, val:0.973767876625061
# LOSS train 0.001980539447245202 valid 0.07045231481486361
# Training vs. Validation Loss {'Training': 0.001980539447245202, 'Validation': 0.07045231481486361} 93
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.973767876625061} 93
# Epoch 93:
# Accuracy train:1.0, val:0.9777424335479736
# LOSS train 0.0012728707522249103 valid 0.056999773785262366
# Training vs. Validation Loss {'Training': 0.0012728707522249103, 'Validation': 0.056999773785262366} 94
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9777424335479736} 94
# Epoch 94:
# Accuracy train:1.0, val:0.970588207244873
# LOSS train 0.001890947673735244 valid 0.08394250949948273
# Training vs. Validation Loss {'Training': 0.001890947673735244, 'Validation': 0.08394250949948273} 95
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.970588207244873} 95
# Epoch 95:
# Accuracy train:1.0, val:0.975357711315155
# LOSS train 0.0014052431028121096 valid 0.06477230255601267
# Training vs. Validation Loss {'Training': 0.0014052431028121096, 'Validation': 0.06477230255601267} 96
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.975357711315155} 96
# Epoch 96:
# Accuracy train:0.9984555840492249, val:0.9658187627792358
# LOSS train 0.0014378992647945063 valid 0.1255812632672059
# Training vs. Validation Loss {'Training': 0.0014378992647945063, 'Validation': 0.1255812632672059} 97
# Training vs. Validation accuracy {'Training': 0.9984555840492249, 'Validation': 0.9658187627792358} 97
# Epoch 97:
# Accuracy train:0.9992278218269348, val:0.9888712167739868
# LOSS train 0.006999989582089422 valid 0.0255300306915547
# Training vs. Validation Loss {'Training': 0.006999989582089422, 'Validation': 0.0255300306915547} 98
# Training vs. Validation accuracy {'Training': 0.9992278218269348, 'Validation': 0.9888712167739868} 98
# Epoch 98:
# Accuracy train:0.9992278218269348, val:0.9642289280891418
# LOSS train 0.004596554119251034 valid 0.13062701009993313
# Training vs. Validation Loss {'Training': 0.004596554119251034, 'Validation': 0.13062701009993313} 99
# Training vs. Validation accuracy {'Training': 0.9992278218269348, 'Validation': 0.9642289280891418} 99
# Epoch 99:
# Accuracy train:0.9984555840492249, val:0.980127215385437
# LOSS train 0.0011349139716582033 valid 0.03609605753801356
# Training vs. Validation Loss {'Training': 0.0011349139716582033, 'Validation': 0.03609605753801356} 100
# Training vs. Validation accuracy {'Training': 0.9984555840492249, 'Validation': 0.980127215385437} 100
# Epoch 100:
# Accuracy train:1.0, val:0.9554848670959473
# LOSS train 0.0025335084113370008 valid 0.16904152146321497
# Training vs. Validation Loss {'Training': 0.0025335084113370008, 'Validation': 0.16904152146321497} 101
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9554848670959473} 101
# Epoch 101:
# Accuracy train:0.9992278218269348, val:0.9586645364761353
# LOSS train 0.0015049313702602926 valid 0.11566992007705784
# Training vs. Validation Loss {'Training': 0.0015049313702602926, 'Validation': 0.11566992007705784} 102
# Training vs. Validation accuracy {'Training': 0.9992278218269348, 'Validation': 0.9586645364761353} 102
# Epoch 102:
# Accuracy train:0.9984555840492249, val:0.9650238752365112
# LOSS train 0.002417476083020588 valid 0.0972127705071691
# Training vs. Validation Loss {'Training': 0.002417476083020588, 'Validation': 0.0972127705071691} 103
# Training vs. Validation accuracy {'Training': 0.9984555840492249, 'Validation': 0.9650238752365112} 103
# Epoch 103:
# Accuracy train:1.0, val:0.9642289280891418
# LOSS train 0.0009748561814459125 valid 0.09180405078064961
# Training vs. Validation Loss {'Training': 0.0009748561814459125, 'Validation': 0.09180405078064961} 104
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9642289280891418} 104
# Epoch 104:
# Accuracy train:0.9992278218269348, val:0.978537380695343
# LOSS train 0.005083988009794142 valid 0.04697002745818973
# Training vs. Validation Loss {'Training': 0.005083988009794142, 'Validation': 0.04697002745818973} 105
# Training vs. Validation accuracy {'Training': 0.9992278218269348, 'Validation': 0.978537380695343} 105
# Epoch 105:
# Accuracy train:1.0, val:0.972178041934967
# LOSS train 0.002426760355636802 valid 0.04842529047051759
# Training vs. Validation Loss {'Training': 0.002426760355636802, 'Validation': 0.04842529047051759} 106
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.972178041934967} 106
# Epoch 106:
# Accuracy train:1.0, val:0.9562798142433167
# LOSS train 0.00234846588996747 valid 0.13805734844566167
# Training vs. Validation Loss {'Training': 0.00234846588996747, 'Validation': 0.13805734844566167} 107
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9562798142433167} 107
# Epoch 107:
# Accuracy train:1.0, val:0.9459459185600281
# LOSS train 0.002091070394574975 valid 0.18828483562503406
# Training vs. Validation Loss {'Training': 0.002091070394574975, 'Validation': 0.18828483562503406} 108
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9459459185600281} 108
# Epoch 108:
# Accuracy train:1.0, val:0.9761525988578796
# LOSS train 0.00294096627145667 valid 0.08096638504943544
# Training vs. Validation Loss {'Training': 0.00294096627145667, 'Validation': 0.08096638504943544} 109
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9761525988578796} 109
# Epoch 109:
# Accuracy train:0.9984555840492249, val:0.9793322682380676
# LOSS train 0.0030808624401150596 valid 0.06937023502462535
# Training vs. Validation Loss {'Training': 0.0030808624401150596, 'Validation': 0.06937023502462535} 110
# Training vs. Validation accuracy {'Training': 0.9984555840492249, 'Validation': 0.9793322682380676} 110
# Epoch 110:
# Accuracy train:0.9992278218269348, val:0.980127215385437
# LOSS train 0.006074205486308501 valid 0.06628445151927145
# Training vs. Validation Loss {'Training': 0.006074205486308501, 'Validation': 0.06628445151927145} 111
# Training vs. Validation accuracy {'Training': 0.9992278218269348, 'Validation': 0.980127215385437} 111
# Epoch 111:
# Accuracy train:1.0, val:0.9697933197021484
# LOSS train 0.0008686200735885932 valid 0.07168821106711167
# Training vs. Validation Loss {'Training': 0.0008686200735885932, 'Validation': 0.07168821106711167} 112
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9697933197021484} 112
# Epoch 112:
# Accuracy train:1.0, val:0.9666136503219604
# LOSS train 0.0012311145164307109 valid 0.10027882021548525
# Training vs. Validation Loss {'Training': 0.0012311145164307109, 'Validation': 0.10027882021548525} 113
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9666136503219604} 113
# Epoch 113:
# Accuracy train:1.0, val:0.9507154226303101
# LOSS train 0.004124457891025072 valid 0.2110735887581336
# Training vs. Validation Loss {'Training': 0.004124457891025072, 'Validation': 0.2110735887581336} 114
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9507154226303101} 114
# Epoch 114:
# Accuracy train:1.0, val:0.9578696489334106
# LOSS train 0.002248084561539475 valid 0.1558050376256618
# Training vs. Validation Loss {'Training': 0.002248084561539475, 'Validation': 0.1558050376256618} 115
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9578696489334106} 115
# Epoch 115:
# Accuracy train:1.0, val:0.9602543711662292
# LOSS train 0.002830715294046306 valid 0.0925981908109824
# Training vs. Validation Loss {'Training': 0.002830715294046306, 'Validation': 0.0925981908109824} 116
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9602543711662292} 116
# Epoch 116:
# Accuracy train:0.9992278218269348, val:0.9451510310173035
# LOSS train 0.0036318395991243465 valid 0.21056377297133777
# Training vs. Validation Loss {'Training': 0.0036318395991243465, 'Validation': 0.21056377297133777} 117
# Training vs. Validation accuracy {'Training': 0.9992278218269348, 'Validation': 0.9451510310173035} 117
# Epoch 117:
# Accuracy train:1.0, val:0.9594594836235046
# LOSS train 0.0019155436361457264 valid 0.10121809445075823
# Training vs. Validation Loss {'Training': 0.0019155436361457264, 'Validation': 0.10121809445075823} 118
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9594594836235046} 118
# Epoch 118:
# Accuracy train:1.0, val:0.9554848670959473
# LOSS train 0.001055155834061831 valid 0.11370152854875408
# Training vs. Validation Loss {'Training': 0.001055155834061831, 'Validation': 0.11370152854875408} 119
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9554848670959473} 119
# Epoch 119:
# Accuracy train:0.9992278218269348, val:0.9562798142433167
# LOSS train 0.0009295850071463395 valid 0.13813192000082217
# Training vs. Validation Loss {'Training': 0.0009295850071463395, 'Validation': 0.13813192000082217} 120
# Training vs. Validation accuracy {'Training': 0.9992278218269348, 'Validation': 0.9562798142433167} 120
# Epoch 120:
# Accuracy train:1.0, val:0.9642289280891418
# LOSS train 0.0005653306932689509 valid 0.07311200020849394
# Training vs. Validation Loss {'Training': 0.0005653306932689509, 'Validation': 0.07311200020849394} 121
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9642289280891418} 121
# Epoch 121:
# Accuracy train:1.0, val:0.9650238752365112
# LOSS train 0.0010145347639054032 valid 0.08486080265690915
# Training vs. Validation Loss {'Training': 0.0010145347639054032, 'Validation': 0.08486080265690915} 122
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9650238752365112} 122
# Epoch 122:
# Accuracy train:1.0, val:0.9602543711662292
# LOSS train 0.004731840719228565 valid 0.12820084657853684
# Training vs. Validation Loss {'Training': 0.004731840719228565, 'Validation': 0.12820084657853684} 123
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9602543711662292} 123
# Epoch 123:
# Accuracy train:1.0, val:0.9483307003974915
# LOSS train 0.002770982369452902 valid 0.20320651728123793
# Training vs. Validation Loss {'Training': 0.002770982369452902, 'Validation': 0.20320651728123793} 124
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9483307003974915} 124
# Epoch 124:
# Accuracy train:0.9992278218269348, val:0.9594594836235046
# LOSS train 0.0010081459779140653 valid 0.13220199449344305
# Training vs. Validation Loss {'Training': 0.0010081459779140653, 'Validation': 0.13220199449344305} 125
# Training vs. Validation accuracy {'Training': 0.9992278218269348, 'Validation': 0.9594594836235046} 125
# Epoch 125:
# Accuracy train:1.0, val:0.9602543711662292
# LOSS train 0.001084592840815083 valid 0.13226857658365632
# Training vs. Validation Loss {'Training': 0.001084592840815083, 'Validation': 0.13226857658365632} 126
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9602543711662292} 126
# Epoch 126:
# Accuracy train:0.9984555840492249, val:0.952305257320404
# LOSS train 0.0018258547033838113 valid 0.1718659771143958
# Training vs. Validation Loss {'Training': 0.0018258547033838113, 'Validation': 0.1718659771143958} 127
# Training vs. Validation accuracy {'Training': 0.9984555840492249, 'Validation': 0.952305257320404} 127
# Epoch 127:
# Accuracy train:0.9984555840492249, val:0.9610492587089539
# LOSS train 0.0005835279229028278 valid 0.1214801879481487
# Training vs. Validation Loss {'Training': 0.0005835279229028278, 'Validation': 0.1214801879481487} 128
# Training vs. Validation accuracy {'Training': 0.9984555840492249, 'Validation': 0.9610492587089539} 128
# stopping at epoch 127, minimum: 0.0255300306915547
# tensor(0.9610)

# %%
list_label = label_dict_from_config_file("hand_gesture.yaml")
DATA_FOLDER_PATH="./data/"
testset = CustomImageDataset(os.path.join(DATA_FOLDER_PATH,"landmark_test.csv"))
test_loader = torch.utils.data.DataLoader(testset, batch_size=20, shuffle=False)

network = NeuralNetwork()
network.load_state_dict(torch.load(best_model_path, weights_only=False))

network.eval()
acc_test = Accuracy(num_classes=len(list_label), task='MULTICLASS')
for i, test_data in enumerate(test_loader):
    test_input, test_label = test_data
    preds = network.predict(test_input)
    acc_test.update(preds, test_label)

print(network.__class__.__name__)
print(f"Accuracy of model:{acc_test.compute().item()}")
print("========================================================================")
# Out:
# NeuralNetwork
# Accuracy of model:0.9552071690559387
# ========================================================================
